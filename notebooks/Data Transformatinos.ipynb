# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# Out:
# /home/ed/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   after removing the cwd from sys.path.

# %%
# %matplotlib notebook
np.set_printoptions(precision=4, linewidth=500, threshold=500, suppress=True)

# %%
import sys
sys.path.append('..')

# %%
from model.features import Features

# %%
logFeatures = Features(transform='log')
normFeatures = Features(transform='norm')
rawFeatures = Features(transform=None)
qantileFeatures = Features(transform='quantile')

# %%
metrics = ['Ozone', 'SO2', 'CO', 'NO2', 'PM25', 'PM10', 'Wind','Pressure', 'Temperature', 'Humidity', 'Fire']

# %%
for tran, features in zip(['Log', 'Normed', 'Raw', 'Quantile'], [logFeatures, normFeatures, rawFeatures, qantileFeatures]):

    fig, axes = plt.subplots(nrows=3, ncols=4, figsize=(12, 6))

    for metric, ax in zip(metrics, axes.flatten()):

        data = features.get_data(metric).values    
        ax.plot(data[:, 0], lw=0.5)

        ax.set_title(metric)
        ax.set_xticks([])

    axes[-1, -1].set_xticks([])
    axes[-1, -1].set_yticks([])
    
    plt.suptitle(tran)
    plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="1200">
# <img src="data:image/png;base64,..." width="1200">
# <img src="data:image/png;base64,..." width="1200">
# <img src="data:image/png;base64,..." width="1200">

# %%
for tran, features in zip(['Log', 'Normed', 'Raw', 'Quantile'], [logFeatures, normFeatures, rawFeatures, qantileFeatures]):

    fig, axes = plt.subplots(nrows=3, ncols=4, figsize=(12, 6))

    for metric, ax in zip(metrics, axes.flatten()):

        data = features.get_data(metric).values    
        
        ax.hist(data.flatten(), bins=100)

        ax.set_title(metric)
        ax.set_xticks([])
        ax.set_yticks([])

    axes[-1, -1].set_xticks([])
    axes[-1, -1].set_yticks([])
    
    plt.suptitle(tran)
    plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="1200">
# <img src="data:image/png;base64,..." width="1200">
# <img src="data:image/png;base64,..." width="1200">
# <img src="data:image/png;base64,..." width="1200">
